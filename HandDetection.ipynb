# %%
import cv2 as cv
from cvzone.HandTrackingModule import HandDetector

cap = cv.VideoCapture(0)
detector = HandDetector(detectionCon=0.5, maxHands=2)

while True:
    ret, frame = cap.read()
    hands, frame = detector.findHands(frame)

    if hands:
        hand = hands[0]
        lm_list = hand["lmList"]  # Landmark list
        hand_type = hand["type"]  # Left or Right Hand

        # Count how many fingers are up
        fingers = []

        # Thumb (for right hand, thumb is up if lmList[4][0] is greater than lmList[3][0])
        if hand_type == "Right":
            fingers.append(1 if lm_list[4][0] > lm_list[3][0] else 0)
        else:  # Left hand
            fingers.append(1 if lm_list[4][0] < lm_list[3][0] else 0)

        # For other fingers (index to pinky)
        for i in range(1, 5):
            # If the tip of the finger is higher than the joint (y-coordinate)
            fingers.append(1 if lm_list[4 * i + 4][1] < lm_list[4 * i + 2][1] else 0)

        total_fingers = fingers.count(1)

        # Display total number of fingers up in the top-left corner
        cv.putText(frame, f"Fingers up: {total_fingers}", (10, 50), 
                   cv.FONT_HERSHEY_SIMPLEX, 1.5, (255, 0, 0), 3)

        # Draw a circle at the center of the hand (for reference)
        total_points = len(lm_list)
        sum_x = sum(point[0] for point in lm_list)
        sum_y = sum(point[1] for point in lm_list)
        center_x = int(sum_x / total_points)
        center_y = int(sum_y / total_points + 50)
        cv.circle(frame, (center_x, center_y), 5, (0, 255, 0), -1)

        # Display distances between fingers (same as your original code)
        finger_indices = [4, 8, 12, 16, 20]  # Thumb, Index, Middle, Ring, Pinky
        for i in range(len(finger_indices) - 1):
            for j in range(i + 1, len(finger_indices)):
                finger1 = lm_list[finger_indices[i]][:-1]
                finger2 = lm_list[finger_indices[j]][:-1]
                length, _, frame = detector.findDistance(finger1, finger2, frame)
                print(f"Distance between finger {i} and finger {j + 1}: {length:.2f} pixels")

    cv.imshow('frame', frame)
    key = cv.waitKey(1)
    if key == 27:  # Escape key to exit
        break

cv.destroyAllWindows()
cap.release()
# Out:
# Distance between finger 0 and finger 2: 108.17 pixels
# Distance between finger 0 and finger 3: 132.64 pixels
# Distance between finger 0 and finger 4: 126.59 pixels
# Distance between finger 0 and finger 5: 137.44 pixels
# Distance between finger 1 and finger 3: 30.61 pixels
# Distance between finger 1 and finger 4: 95.52 pixels
# Distance between finger 1 and finger 5: 110.32 pixels
# Distance between finger 2 and finger 4: 85.48 pixels
# Distance between finger 2 and finger 5: 98.90 pixels
# Distance between finger 3 and finger 5: 15.00 pixels
# Distance between finger 0 and finger 2: 105.39 pixels
# Distance between finger 0 and finger 3: 127.19 pixels
# Distance between finger 0 and finger 4: 131.05 pixels
# Distance between finger 0 and finger 5: 137.93 pixels
# Distance between finger 1 and finger 3: 27.20 pixels
# Distance between finger 1 and finger 4: 96.25 pixels
# Distance between finger 1 and finger 5: 104.12 pixels
# Distance between finger 2 and finger 4: 85.09 pixels
# Distance between finger 2 and finger 5: 92.05 pixels
# Distance between finger 3 and finger 5: 8.25 pixels
# Distance between finger 0 and finger 2: 105.39 pixels
# Distance between finger 0 and finger 3: 129.14 pixels
# Distance between finger 0 and finger 4: 130.91 pixels
# Distance between finger 0 and finger 5: 135.10 pixels
# Distance between finger 1 and finger 3: 28.30 pixels
# Distance between finger 1 and finger 4: 98.41 pixels
# Distance between finger 1 and finger 5: 102.24 pixels
# Distance between finger 2 and finger 4: 89.32 pixels
# Distance between finger 2 and finger 5: 92.36 pixels
# Distance between finger 3 and finger 5: 4.47 pixels
# Distance between finger 0 and finger 2: 105.08 pixels
# Distance between finger 0 and finger 3: 126.00 pixels
# Distance between finger 0 and finger 4: 128.32 pixels
# Distance between finger 0 and finger 5: 132.38 pixels
# Distance between finger 1 and finger 3: 26.63 pixels
# Distance between finger 1 and finger 4: 99.25 pixels
# Distance between finger 1 and finger 5: 104.17 pixels
# Distance between finger 2 and finger 4: 88.87 pixels
# Distance between finger 2 and finger 5: 93.30 pixels
# Distance between finger 3 and finger 5: 5.10 pixels
# Distance between finger 0 and finger 2: 90.52 pixels
# Distance between finger 0 and finger 3: 108.02 pixels
# Distance between finger 0 and finger 4: 117.41 pixels
# Distance between finger 0 and finger 5: 121.51 pixels
# Distance between finger 1 and finger 3: 31.14 pixels
# Distance between finger 1 and finger 4: 110.16 pixels
# Distance between finger 1 and finger 5: 119.42 pixels
# Distance between finger 2 and finger 4: 91.09 pixels
# Distance between finger 2 and finger 5: 100.88 pixels
# Distance between finger 3 and finger 5: 9.85 pixels
# Distance between finger 0 and finger 2: 67.12 pixels
# Distance between finger 0 and finger 3: 88.20 pixels
# Distance between finger 0 and finger 4: 101.41 pixels
# Distance between finger 0 and finger 5: 104.20 pixels
# Distance between finger 1 and finger 3: 34.83 pixels
# Distance between finger 1 and finger 4: 105.12 pixels
# Distance between finger 1 and finger 5: 111.02 pixels
# Distance between finger 2 and finger 4: 85.87 pixels
# Distance between finger 2 and finger 5: 92.44 pixels
# Distance between finger 3 and finger 5: 6.71 pixels
# Distance between finger 0 and finger 2: 45.18 pixels
# Distance between finger 0 and finger 3: 66.65 pixels
# Distance between finger 0 and finger 4: 79.32 pixels
# Distance between finger 0 and finger 5: 74.03 pixels
# Distance between finger 1 and finger 3: 21.47 pixels
# Distance between finger 1 and finger 4: 34.71 pixels
# Distance between finger 1 and finger 5: 37.48 pixels
# Distance between finger 2 and finger 4: 14.76 pixels
# Distance between finger 2 and finger 5: 29.97 pixels
# Distance between finger 3 and finger 5: 24.41 pixels
# Distance between finger 0 and finger 2: 42.72 pixels
# Distance between finger 0 and finger 3: 64.40 pixels
# Distance between finger 0 and finger 4: 72.11 pixels
# Distance between finger 0 and finger 5: 67.48 pixels
# Distance between finger 1 and finger 3: 22.20 pixels
# Distance between finger 1 and finger 4: 32.02 pixels
# Distance between finger 1 and finger 5: 37.12 pixels
# Distance between finger 2 and finger 4: 12.17 pixels
# Distance between finger 2 and finger 5: 28.30 pixels
# Distance between finger 3 and finger 5: 20.81 pixels
# Distance between finger 0 and finger 2: 45.22 pixels
# Distance between finger 0 and finger 3: 66.21 pixels
# Distance between finger 0 and finger 4: 74.09 pixels
# Distance between finger 0 and finger 5: 68.68 pixels
# Distance between finger 1 and finger 3: 22.02 pixels
# Distance between finger 1 and finger 4: 32.02 pixels
# Distance between finger 1 and finger 5: 37.12 pixels
# Distance between finger 2 and finger 4: 11.40 pixels
# Distance between finger 2 and finger 5: 26.93 pixels
# Distance between finger 3 and finger 5: 20.81 pixels
# Distance between finger 0 and finger 2: 49.50 pixels
# Distance between finger 0 and finger 3: 67.45 pixels
# Distance between finger 0 and finger 4: 73.82 pixels
# Distance between finger 0 and finger 5: 65.76 pixels
# Distance between finger 1 and finger 3: 19.42 pixels
# Distance between finger 1 and finger 4: 30.00 pixels
# Distance between finger 1 and finger 5: 39.05 pixels
# Distance between finger 2 and finger 4: 13.15 pixels
# Distance between finger 2 and finger 5: 33.29 pixels
# Distance between finger 3 and finger 5: 25.00 pixels
# Distance between finger 0 and finger 2: 44.15 pixels
# Distance between finger 0 and finger 3: 65.46 pixels
# Distance between finger 0 and finger 4: 72.47 pixels
# Distance between finger 0 and finger 5: 70.01 pixels
# Distance between finger 1 and finger 3: 21.95 pixels
# Distance between finger 1 and finger 4: 31.89 pixels
# Distance between finger 1 and finger 5: 39.62 pixels
# Distance between finger 2 and finger 4: 13.15 pixels
# Distance between finger 2 and finger 5: 30.46 pixels
# Distance between finger 3 and finger 5: 20.52 pixels
# Distance between finger 0 and finger 2: 42.45 pixels
# Distance between finger 0 and finger 3: 60.73 pixels
# Distance between finger 0 and finger 4: 71.55 pixels
# Distance between finger 0 and finger 5: 67.18 pixels
# Distance between finger 1 and finger 3: 18.38 pixels
# Distance between finger 1 and finger 4: 31.14 pixels
# Distance between finger 1 and finger 5: 36.67 pixels
# Distance between finger 2 and finger 4: 15.23 pixels
# Distance between finger 2 and finger 5: 30.68 pixels
# Distance between finger 3 and finger 5: 21.93 pixels
# Distance between finger 0 and finger 2: 46.69 pixels
# Distance between finger 0 and finger 3: 62.63 pixels
# Distance between finger 0 and finger 4: 72.07 pixels
# Distance between finger 0 and finger 5: 70.77 pixels
# Distance between finger 1 and finger 3: 18.38 pixels
# Distance between finger 1 and finger 4: 31.91 pixels
# Distance between finger 1 and finger 5: 40.45 pixels
# Distance between finger 2 and finger 4: 14.56 pixels
# Distance between finger 2 and finger 5: 27.89 pixels
# Distance between finger 3 and finger 5: 17.03 pixels
# Distance between finger 0 and finger 2: 45.40 pixels
# Distance between finger 0 and finger 3: 57.58 pixels
# Distance between finger 0 and finger 4: 66.73 pixels
# Distance between finger 0 and finger 5: 70.18 pixels
# Distance between finger 1 and finger 3: 16.64 pixels
# Distance between finger 1 and finger 4: 29.97 pixels
# Distance between finger 1 and finger 5: 47.01 pixels
# Distance between finger 2 and finger 4: 13.60 pixels
# Distance between finger 2 and finger 5: 33.96 pixels
# Distance between finger 3 and finger 5: 23.32 pixels
# Distance between finger 0 and finger 2: 12.21 pixels
# Distance between finger 0 and finger 3: 19.65 pixels
# Distance between finger 0 and finger 4: 34.06 pixels
# Distance between finger 0 and finger 5: 52.47 pixels
# Distance between finger 1 and finger 3: 13.00 pixels
# Distance between finger 1 and finger 4: 29.55 pixels
# Distance between finger 1 and finger 5: 48.10 pixels
# Distance between finger 2 and finger 4: 16.55 pixels
# Distance between finger 2 and finger 5: 35.11 pixels
# Distance between finger 3 and finger 5: 18.68 pixels
# Distance between finger 0 and finger 2: 15.62 pixels
# Distance between finger 0 and finger 3: 21.54 pixels
# Distance between finger 0 and finger 4: 35.13 pixels
# Distance between finger 0 and finger 5: 52.01 pixels
# Distance between finger 1 and finger 3: 8.25 pixels
# Distance between finger 1 and finger 4: 24.04 pixels
# Distance between finger 1 and finger 5: 41.48 pixels
# Distance between finger 2 and finger 4: 15.81 pixels
# Distance between finger 2 and finger 5: 33.24 pixels
# Distance between finger 3 and finger 5: 17.46 pixels
# Distance between finger 0 and finger 2: 11.70 pixels
# Distance between finger 0 and finger 3: 18.44 pixels
# Distance between finger 0 and finger 4: 32.02 pixels
# Distance between finger 0 and finger 5: 51.62 pixels
# Distance between finger 1 and finger 3: 15.65 pixels
# Distance between finger 1 and finger 4: 30.46 pixels
# Distance between finger 1 and finger 5: 50.70 pixels
# Distance between finger 2 and finger 4: 14.87 pixels
# Distance between finger 2 and finger 5: 35.11 pixels
# Distance between finger 3 and finger 5: 20.25 pixels
# Distance between finger 0 and finger 2: 10.77 pixels
# Distance between finger 0 and finger 3: 13.15 pixels
# Distance between finger 0 and finger 4: 28.28 pixels
# Distance between finger 0 and finger 5: 51.66 pixels
# Distance between finger 1 and finger 3: 18.79 pixels
# Distance between finger 1 and finger 4: 34.93 pixels
# Distance between finger 1 and finger 5: 58.69 pixels
# Distance between finger 2 and finger 4: 16.16 pixels
# Distance between finger 2 and finger 5: 39.92 pixels
# Distance between finger 3 and finger 5: 23.77 pixels
# Distance between finger 0 and finger 2: 10.20 pixels
# Distance between finger 0 and finger 3: 17.46 pixels
# Distance between finger 0 and finger 4: 33.06 pixels
# Distance between finger 0 and finger 5: 51.62 pixels
# Distance between finger 1 and finger 3: 16.16 pixels
# Distance between finger 1 and finger 4: 33.24 pixels
# Distance between finger 1 and finger 5: 52.20 pixels
# Distance between finger 2 and finger 4: 17.09 pixels
# Distance between finger 2 and finger 5: 36.06 pixels
# Distance between finger 3 and finger 5: 18.97 pixels
# Distance between finger 0 and finger 2: 11.40 pixels
# Distance between finger 0 and finger 3: 18.44 pixels
# Distance between finger 0 and finger 4: 34.01 pixels
# Distance between finger 0 and finger 5: 53.76 pixels
# Distance between finger 1 and finger 3: 16.55 pixels
# Distance between finger 1 and finger 4: 33.24 pixels
# Distance between finger 1 and finger 5: 53.85 pixels
# Distance between finger 2 and finger 4: 16.76 pixels
# Distance between finger 2 and finger 5: 37.34 pixels
# Distance between finger 3 and finger 5: 20.62 pixels
# Distance between finger 0 and finger 2: 11.31 pixels
# Distance between finger 0 and finger 3: 20.02 pixels
# Distance between finger 0 and finger 4: 36.22 pixels
# Distance between finger 0 and finger 5: 53.15 pixels
# Distance between finger 1 and finger 3: 13.89 pixels
# Distance between finger 1 and finger 4: 30.46 pixels
# Distance between finger 1 and finger 5: 47.93 pixels
# Distance between finger 2 and finger 4: 16.76 pixels
# Distance between finger 2 and finger 5: 34.18 pixels
# Distance between finger 3 and finger 5: 17.46 pixels
# Distance between finger 0 and finger 2: 32.65 pixels
# Distance between finger 0 and finger 3: 33.42 pixels
# Distance between finger 0 and finger 4: 38.60 pixels
# Distance between finger 0 and finger 5: 37.22 pixels
# Distance between finger 1 and finger 3: 1.00 pixels
# Distance between finger 1 and finger 4: 6.32 pixels
# Distance between finger 1 and finger 5: 7.28 pixels
# Distance between finger 2 and finger 4: 5.39 pixels
# Distance between finger 2 and finger 5: 6.32 pixels
# Distance between finger 3 and finger 5: 4.12 pixels
# Distance between finger 0 and finger 2: 97.05 pixels
# Distance between finger 0 and finger 3: 129.02 pixels
# Distance between finger 0 and finger 4: 142.80 pixels
# Distance between finger 0 and finger 5: 152.32 pixels
# Distance between finger 1 and finger 3: 39.00 pixels
# Distance between finger 1 and finger 4: 71.01 pixels
# Distance between finger 1 and finger 5: 100.69 pixels
# Distance between finger 2 and finger 4: 38.48 pixels
# Distance between finger 2 and finger 5: 74.06 pixels
# Distance between finger 3 and finger 5: 36.77 pixels
# Distance between finger 0 and finger 2: 99.30 pixels
# Distance between finger 0 and finger 3: 125.61 pixels
# Distance between finger 0 and finger 4: 136.50 pixels
# Distance between finger 0 and finger 5: 141.33 pixels
# Distance between finger 1 and finger 3: 35.90 pixels
# Distance between finger 1 and finger 4: 60.03 pixels
# Distance between finger 1 and finger 5: 85.07 pixels
# Distance between finger 2 and finger 4: 26.93 pixels
# Distance between finger 2 and finger 5: 57.20 pixels
# Distance between finger 3 and finger 5: 31.89 pixels
# Distance between finger 0 and finger 2: 95.52 pixels
# Distance between finger 0 and finger 3: 123.04 pixels
# Distance between finger 0 and finger 4: 130.36 pixels
# Distance between finger 0 and finger 5: 129.81 pixels
# Distance between finger 1 and finger 3: 37.48 pixels
# Distance between finger 1 and finger 4: 59.68 pixels
# Distance between finger 1 and finger 5: 80.06 pixels
# Distance between finger 2 and finger 4: 26.63 pixels
# Distance between finger 2 and finger 5: 53.91 pixels
# Distance between finger 3 and finger 5: 29.07 pixels
# Distance between finger 0 and finger 2: 103.47 pixels
# Distance between finger 0 and finger 3: 132.06 pixels
# Distance between finger 0 and finger 4: 141.77 pixels
# Distance between finger 0 and finger 5: 153.40 pixels
# Distance between finger 1 and finger 3: 37.34 pixels
# Distance between finger 1 and finger 4: 66.03 pixels
# Distance between finger 1 and finger 5: 100.96 pixels
# Distance between finger 2 and finger 4: 34.44 pixels
# Distance between finger 2 and finger 5: 74.33 pixels
# Distance between finger 3 and finger 5: 40.46 pixels
# Distance between finger 0 and finger 2: 107.94 pixels
# Distance between finger 0 and finger 3: 134.24 pixels
# Distance between finger 0 and finger 4: 147.25 pixels
# Distance between finger 0 and finger 5: 154.83 pixels
# Distance between finger 1 and finger 3: 33.62 pixels
# Distance between finger 1 and finger 4: 66.00 pixels
# Distance between finger 1 and finger 5: 96.30 pixels
# Distance between finger 2 and finger 4: 37.34 pixels
# Distance between finger 2 and finger 5: 72.72 pixels
# Distance between finger 3 and finger 5: 36.80 pixels
# Distance between finger 0 and finger 2: 102.16 pixels
# Distance between finger 0 and finger 3: 132.31 pixels
# Distance between finger 0 and finger 4: 143.93 pixels
# Distance between finger 0 and finger 5: 156.52 pixels
# Distance between finger 1 and finger 3: 38.08 pixels
# Distance between finger 1 and finger 4: 69.00 pixels
# Distance between finger 1 and finger 5: 102.84 pixels
# Distance between finger 2 and finger 4: 37.16 pixels
# Distance between finger 2 and finger 5: 75.80 pixels
# Distance between finger 3 and finger 5: 39.20 pixels
# Distance between finger 0 and finger 2: 107.35 pixels
# Distance between finger 0 and finger 3: 138.81 pixels
# Distance between finger 0 and finger 4: 149.68 pixels
# Distance between finger 0 and finger 5: 154.95 pixels
# Distance between finger 1 and finger 3: 39.00 pixels
# Distance between finger 1 and finger 4: 68.00 pixels
# Distance between finger 1 and finger 5: 102.18 pixels
# Distance between finger 2 and finger 4: 35.34 pixels
# Distance between finger 2 and finger 5: 78.10 pixels
# Distance between finger 3 and finger 5: 44.82 pixels
# Distance between finger 0 and finger 2: 109.57 pixels
# Distance between finger 0 and finger 3: 141.82 pixels
# Distance between finger 0 and finger 4: 153.67 pixels
# Distance between finger 0 and finger 5: 165.15 pixels
# Distance between finger 1 and finger 3: 40.50 pixels
# Distance between finger 1 and finger 4: 71.03 pixels
# Distance between finger 1 and finger 5: 113.65 pixels
# Distance between finger 2 and finger 4: 36.67 pixels
# Distance between finger 2 and finger 5: 87.46 pixels
# Distance between finger 3 and finger 5: 52.40 pixels
# Distance between finger 0 and finger 2: 104.12 pixels
# Distance between finger 0 and finger 3: 130.94 pixels
# Distance between finger 0 and finger 4: 130.08 pixels
# Distance between finger 0 and finger 5: 141.83 pixels
# Distance between finger 1 and finger 3: 39.96 pixels
# Distance between finger 1 and finger 4: 66.19 pixels
# Distance between finger 1 and finger 5: 119.82 pixels
# Distance between finger 2 and finger 4: 35.78 pixels
# Distance between finger 2 and finger 5: 96.57 pixels
# Distance between finger 3 and finger 5: 61.03 pixels
# Distance between finger 0 and finger 2: 99.33 pixels
# Distance between finger 0 and finger 3: 138.42 pixels
# Distance between finger 0 and finger 4: 150.01 pixels
# Distance between finger 0 and finger 5: 172.63 pixels
# Distance between finger 1 and finger 3: 47.17 pixels
# Distance between finger 1 and finger 4: 74.53 pixels
# Distance between finger 1 and finger 5: 126.15 pixels
# Distance between finger 2 and finger 4: 34.48 pixels
# Distance between finger 2 and finger 5: 94.81 pixels
# Distance between finger 3 and finger 5: 61.06 pixels
# Distance between finger 0 and finger 2: 100.69 pixels
# Distance between finger 0 and finger 3: 139.29 pixels
# Distance between finger 0 and finger 4: 149.97 pixels
# Distance between finger 0 and finger 5: 173.52 pixels
# Distance between finger 1 and finger 3: 48.37 pixels
# Distance between finger 1 and finger 4: 76.94 pixels
# Distance between finger 1 and finger 5: 129.40 pixels
# Distance between finger 2 and finger 4: 36.06 pixels
# Distance between finger 2 and finger 5: 96.15 pixels
# Distance between finger 3 and finger 5: 60.54 pixels
# Distance between finger 0 and finger 2: 101.87 pixels
# Distance between finger 0 and finger 3: 137.93 pixels
# Distance between finger 0 and finger 4: 147.87 pixels
# Distance between finger 0 and finger 5: 173.09 pixels
# Distance between finger 1 and finger 3: 48.75 pixels
# Distance between finger 1 and finger 4: 77.52 pixels
# Distance between finger 1 and finger 5: 134.16 pixels
# Distance between finger 2 and finger 4: 35.11 pixels
# Distance between finger 2 and finger 5: 98.84 pixels
# Distance between finger 3 and finger 5: 64.14 pixels
# Distance between finger 0 and finger 2: 101.95 pixels
# Distance between finger 0 and finger 3: 141.74 pixels
# Distance between finger 0 and finger 4: 153.52 pixels
# Distance between finger 0 and finger 5: 178.31 pixels
# Distance between finger 1 and finger 3: 46.65 pixels
# Distance between finger 1 and finger 4: 75.66 pixels
# Distance between finger 1 and finger 5: 129.44 pixels
# Distance between finger 2 and finger 4: 37.70 pixels
# Distance between finger 2 and finger 5: 99.85 pixels
# Distance between finger 3 and finger 5: 62.68 pixels
# Distance between finger 0 and finger 2: 105.48 pixels
# Distance between finger 0 and finger 3: 142.58 pixels
# Distance between finger 0 and finger 4: 155.67 pixels
# Distance between finger 0 and finger 5: 178.31 pixels
# Distance between finger 1 and finger 3: 43.91 pixels
# Distance between finger 1 and finger 4: 75.43 pixels
# Distance between finger 1 and finger 5: 128.10 pixels
# Distance between finger 2 and finger 4: 39.56 pixels
# Distance between finger 2 and finger 5: 100.34 pixels
# Distance between finger 3 and finger 5: 61.61 pixels
# Distance between finger 0 and finger 2: 105.48 pixels
# Distance between finger 0 and finger 3: 142.28 pixels
# Distance between finger 0 and finger 4: 156.31 pixels
# Distance between finger 0 and finger 5: 177.79 pixels
# Distance between finger 1 and finger 3: 44.29 pixels
# Distance between finger 1 and finger 4: 74.67 pixels
# Distance between finger 1 and finger 5: 126.91 pixels
# Distance between finger 2 and finger 4: 36.69 pixels
# Distance between finger 2 and finger 5: 97.62 pixels
# Distance between finger 3 and finger 5: 62.20 pixels
# Distance between finger 0 and finger 2: 103.62 pixels
# Distance between finger 0 and finger 3: 143.67 pixels
# Distance between finger 0 and finger 4: 158.49 pixels
# Distance between finger 0 and finger 5: 180.02 pixels
# Distance between finger 1 and finger 3: 46.65 pixels
# Distance between finger 1 and finger 4: 77.93 pixels
# Distance between finger 1 and finger 5: 128.27 pixels
# Distance between finger 2 and finger 4: 38.90 pixels
# Distance between finger 2 and finger 5: 98.49 pixels
# Distance between finger 3 and finger 5: 60.80 pixels
# Distance between finger 0 and finger 2: 103.25 pixels
# Distance between finger 0 and finger 3: 143.12 pixels
# Distance between finger 0 and finger 4: 157.04 pixels
# Distance between finger 0 and finger 5: 179.11 pixels
# Distance between finger 1 and finger 3: 46.65 pixels
# Distance between finger 1 and finger 4: 76.94 pixels
# Distance between finger 1 and finger 5: 128.27 pixels
# Distance between finger 2 and finger 4: 37.95 pixels
# Distance between finger 2 and finger 5: 98.49 pixels
# Distance between finger 3 and finger 5: 61.61 pixels
# Distance between finger 0 and finger 2: 81.32 pixels
# Distance between finger 0 and finger 3: 107.91 pixels
# Distance between finger 0 and finger 4: 120.49 pixels
# Distance between finger 0 and finger 5: 147.14 pixels
# Distance between finger 1 and finger 3: 70.88 pixels
# Distance between finger 1 and finger 4: 99.01 pixels
# Distance between finger 1 and finger 5: 133.02 pixels
# Distance between finger 2 and finger 4: 29.83 pixels
# Distance between finger 2 and finger 5: 63.29 pixels
# Distance between finger 3 and finger 5: 34.01 pixels
# Distance between finger 0 and finger 2: 100.09 pixels
# Distance between finger 0 and finger 3: 47.85 pixels
# Distance between finger 0 and finger 4: 69.40 pixels
# Distance between finger 0 and finger 5: 80.16 pixels
# Distance between finger 1 and finger 3: 147.85 pixels
# Distance between finger 1 and finger 4: 168.18 pixels
# Distance between finger 1 and finger 5: 175.01 pixels
# Distance between finger 2 and finger 4: 23.85 pixels
# Distance between finger 2 and finger 5: 41.00 pixels
# Distance between finger 3 and finger 5: 20.40 pixels
# Distance between finger 0 and finger 2: 111.02 pixels
# Distance between finger 0 and finger 3: 46.10 pixels
# Distance between finger 0 and finger 4: 62.82 pixels
# Distance between finger 0 and finger 5: 64.90 pixels
# Distance between finger 1 and finger 3: 149.47 pixels
# Distance between finger 1 and finger 4: 170.88 pixels
# Distance between finger 1 and finger 5: 175.89 pixels
# Distance between finger 2 and finger 4: 23.43 pixels
# Distance between finger 2 and finger 5: 39.81 pixels
# Distance between finger 3 and finger 5: 22.14 pixels
# Distance between finger 0 and finger 2: 112.41 pixels
# Distance between finger 0 and finger 3: 40.61 pixels
# Distance between finger 0 and finger 4: 61.98 pixels
# Distance between finger 0 and finger 5: 65.00 pixels
# Distance between finger 1 and finger 3: 143.67 pixels
# Distance between finger 1 and finger 4: 170.39 pixels
# Distance between finger 1 and finger 5: 177.23 pixels
# Distance between finger 2 and finger 4: 27.66 pixels
# Distance between finger 2 and finger 5: 43.08 pixels
# Distance between finger 3 and finger 5: 22.56 pixels
# Distance between finger 0 and finger 2: 108.72 pixels
# Distance between finger 0 and finger 3: 50.01 pixels
# Distance between finger 0 and finger 4: 66.94 pixels
# Distance between finger 0 and finger 5: 72.20 pixels
# Distance between finger 1 and finger 3: 152.32 pixels
# Distance between finger 1 and finger 4: 173.07 pixels
# Distance between finger 1 and finger 5: 180.85 pixels
# Distance between finger 2 and finger 4: 22.67 pixels
# Distance between finger 2 and finger 5: 39.85 pixels
# Distance between finger 3 and finger 5: 21.21 pixels
# Distance between finger 0 and finger 2: 113.74 pixels
# Distance between finger 0 and finger 3: 49.04 pixels
# Distance between finger 0 and finger 4: 63.06 pixels
# Distance between finger 0 and finger 5: 68.80 pixels
# Distance between finger 1 and finger 3: 156.54 pixels
# Distance between finger 1 and finger 4: 174.87 pixels
# Distance between finger 1 and finger 5: 182.54 pixels
# Distance between finger 2 and finger 4: 21.63 pixels
# Distance between finger 2 and finger 5: 40.02 pixels
# Distance between finger 3 and finger 5: 21.21 pixels
# Distance between finger 0 and finger 2: 86.61 pixels
# Distance between finger 0 and finger 3: 41.19 pixels
# Distance between finger 0 and finger 4: 61.68 pixels
# Distance between finger 0 and finger 5: 68.60 pixels
# Distance between finger 1 and finger 3: 123.88 pixels
# Distance between finger 1 and finger 4: 146.86 pixels
# Distance between finger 1 and finger 5: 155.21 pixels
# Distance between finger 2 and finger 4: 24.04 pixels
# Distance between finger 2 and finger 5: 39.56 pixels
# Distance between finger 3 and finger 5: 20.22 pixels
# Distance between finger 0 and finger 2: 116.25 pixels
# Distance between finger 0 and finger 3: 18.25 pixels
# Distance between finger 0 and finger 4: 59.77 pixels
# Distance between finger 0 and finger 5: 70.49 pixels
# Distance between finger 1 and finger 3: 104.06 pixels
# Distance between finger 1 and finger 4: 174.15 pixels
# Distance between finger 1 and finger 5: 186.66 pixels
# Distance between finger 2 and finger 4: 76.49 pixels
# Distance between finger 2 and finger 5: 85.09 pixels
# Distance between finger 3 and finger 5: 19.24 pixels
# Distance between finger 0 and finger 2: 137.19 pixels
# Distance between finger 0 and finger 3: 99.98 pixels
# Distance between finger 0 and finger 4: 28.79 pixels
# Distance between finger 0 and finger 5: 43.93 pixels
# Distance between finger 1 and finger 3: 82.01 pixels
# Distance between finger 1 and finger 4: 151.73 pixels
# Distance between finger 1 and finger 5: 175.80 pixels
# Distance between finger 2 and finger 4: 126.06 pixels
# Distance between finger 2 and finger 5: 143.85 pixels
# Distance between finger 3 and finger 5: 24.84 pixels
# Distance between finger 0 and finger 2: 149.91 pixels
# Distance between finger 0 and finger 3: 131.94 pixels
# Distance between finger 0 and finger 4: 24.17 pixels
# Distance between finger 0 and finger 5: 34.23 pixels
# Distance between finger 1 and finger 3: 78.45 pixels
# Distance between finger 1 and finger 4: 159.81 pixels
# Distance between finger 1 and finger 5: 177.88 pixels
# Distance between finger 2 and finger 4: 151.60 pixels
# Distance between finger 2 and finger 5: 165.95 pixels
# Distance between finger 3 and finger 5: 18.44 pixels
# Distance between finger 0 and finger 2: 149.91 pixels
# Distance between finger 0 and finger 3: 134.39 pixels
# Distance between finger 0 and finger 4: 22.80 pixels
# Distance between finger 0 and finger 5: 35.69 pixels
# Distance between finger 1 and finger 3: 78.75 pixels
# Distance between finger 1 and finger 4: 162.61 pixels
# Distance between finger 1 and finger 5: 180.85 pixels
# Distance between finger 2 and finger 4: 154.87 pixels
# Distance between finger 2 and finger 5: 170.07 pixels
# Distance between finger 3 and finger 5: 18.38 pixels
# Distance between finger 0 and finger 2: 147.80 pixels
# Distance between finger 0 and finger 3: 130.25 pixels
# Distance between finger 0 and finger 4: 27.51 pixels
# Distance between finger 0 and finger 5: 39.46 pixels
# Distance between finger 1 and finger 3: 76.54 pixels
# Distance between finger 1 and finger 4: 161.40 pixels
# Distance between finger 1 and finger 5: 180.85 pixels
# Distance between finger 2 and finger 4: 153.88 pixels
# Distance between finger 2 and finger 5: 169.55 pixels
# Distance between finger 3 and finger 5: 19.85 pixels
# Distance between finger 0 and finger 2: 147.09 pixels
# Distance between finger 0 and finger 3: 129.76 pixels
# Distance between finger 0 and finger 4: 25.71 pixels
# Distance between finger 0 and finger 5: 37.85 pixels
# Distance between finger 1 and finger 3: 75.00 pixels
# Distance between finger 1 and finger 4: 162.20 pixels
# Distance between finger 1 and finger 5: 180.24 pixels
# Distance between finger 2 and finger 4: 153.06 pixels
# Distance between finger 2 and finger 5: 167.60 pixels
# Distance between finger 3 and finger 5: 18.44 pixels
# Distance between finger 0 and finger 2: 144.69 pixels
# Distance between finger 0 and finger 3: 81.88 pixels
# Distance between finger 0 and finger 4: 21.26 pixels
# Distance between finger 0 and finger 5: 20.40 pixels
# Distance between finger 1 and finger 3: 66.85 pixels
# Distance between finger 1 and finger 4: 123.69 pixels
# Distance between finger 1 and finger 5: 158.11 pixels
# Distance between finger 2 and finger 4: 62.39 pixels
# Distance between finger 2 and finger 5: 98.43 pixels
# Distance between finger 3 and finger 5: 36.06 pixels
# Distance between finger 0 and finger 2: 153.45 pixels
# Distance between finger 0 and finger 3: 125.72 pixels
# Distance between finger 0 and finger 4: 90.35 pixels
# Distance between finger 0 and finger 5: 14.04 pixels
# Distance between finger 1 and finger 3: 63.03 pixels
# Distance between finger 1 and finger 4: 103.12 pixels
# Distance between finger 1 and finger 5: 162.74 pixels
# Distance between finger 2 and finger 4: 47.38 pixels
# Distance between finger 2 and finger 5: 130.29 pixels
# Distance between finger 3 and finger 5: 91.20 pixels
# Distance between finger 0 and finger 2: 155.79 pixels
# Distance between finger 0 and finger 3: 139.86 pixels
# Distance between finger 0 and finger 4: 110.04 pixels
# Distance between finger 0 and finger 5: 14.14 pixels
# Distance between finger 1 and finger 3: 57.01 pixels
# Distance between finger 1 and finger 4: 101.18 pixels
# Distance between finger 1 and finger 5: 165.24 pixels
# Distance between finger 2 and finger 4: 50.57 pixels
# Distance between finger 2 and finger 5: 152.43 pixels
# Distance between finger 3 and finger 5: 124.00 pixels
# Distance between finger 0 and finger 2: 154.94 pixels
# Distance between finger 0 and finger 3: 144.18 pixels
# Distance between finger 0 and finger 4: 114.35 pixels
# Distance between finger 0 and finger 5: 22.36 pixels
# Distance between finger 1 and finger 3: 51.62 pixels
# Distance between finger 1 and finger 4: 97.01 pixels
# Distance between finger 1 and finger 5: 169.20 pixels
# Distance between finger 2 and finger 4: 52.20 pixels
# Distance between finger 2 and finger 5: 163.19 pixels
# Distance between finger 3 and finger 5: 136.09 pixels
# Distance between finger 0 and finger 2: 158.49 pixels
# Distance between finger 0 and finger 3: 147.73 pixels
# Distance between finger 0 and finger 4: 120.60 pixels
# Distance between finger 0 and finger 5: 16.49 pixels
# Distance between finger 1 and finger 3: 51.62 pixels
# Distance between finger 1 and finger 4: 96.08 pixels
# Distance between finger 1 and finger 5: 168.05 pixels
# Distance between finger 2 and finger 4: 50.29 pixels
# Distance between finger 2 and finger 5: 161.05 pixels
# Distance between finger 3 and finger 5: 136.24 pixels
# Distance between finger 0 and finger 2: 153.39 pixels
# Distance between finger 0 and finger 3: 150.99 pixels
# Distance between finger 0 and finger 4: 121.07 pixels
# Distance between finger 0 and finger 5: 9.49 pixels
# Distance between finger 1 and finger 3: 49.65 pixels
# Distance between finger 1 and finger 4: 94.05 pixels
# Distance between finger 1 and finger 5: 162.27 pixels
# Distance between finger 2 and finger 4: 53.85 pixels
# Distance between finger 2 and finger 5: 160.46 pixels
# Distance between finger 3 and finger 5: 130.19 pixels
# Distance between finger 0 and finger 2: 159.18 pixels
# Distance between finger 0 and finger 3: 150.31 pixels
# Distance between finger 0 and finger 4: 116.84 pixels
# Distance between finger 0 and finger 5: 19.42 pixels
# Distance between finger 1 and finger 3: 49.24 pixels
# Distance between finger 1 and finger 4: 95.00 pixels
# Distance between finger 1 and finger 5: 171.03 pixels
# Distance between finger 2 and finger 4: 53.85 pixels
# Distance between finger 2 and finger 5: 166.21 pixels
# Distance between finger 3 and finger 5: 135.37 pixels
# Distance between finger 0 and finger 2: 151.82 pixels
# Distance between finger 0 and finger 3: 150.55 pixels
# Distance between finger 0 and finger 4: 118.00 pixels
# Distance between finger 0 and finger 5: 9.22 pixels
# Distance between finger 1 and finger 3: 48.30 pixels
# Distance between finger 1 and finger 4: 94.02 pixels
# Distance between finger 1 and finger 5: 160.86 pixels
# Distance between finger 2 and finger 4: 56.36 pixels
# Distance between finger 2 and finger 5: 158.60 pixels
# Distance between finger 3 and finger 5: 124.15 pixels
# Distance between finger 0 and finger 2: 159.29 pixels
# Distance between finger 0 and finger 3: 151.70 pixels
# Distance between finger 0 and finger 4: 119.71 pixels
# Distance between finger 0 and finger 5: 12.65 pixels
# Distance between finger 1 and finger 3: 48.33 pixels
# Distance between finger 1 and finger 4: 94.01 pixels
# Distance between finger 1 and finger 5: 165.86 pixels
# Distance between finger 2 and finger 4: 53.49 pixels
# Distance between finger 2 and finger 5: 161.19 pixels
# Distance between finger 3 and finger 5: 131.31 pixels
# Distance between finger 0 and finger 2: 152.00 pixels
# Distance between finger 0 and finger 3: 153.71 pixels
# Distance between finger 0 and finger 4: 120.00 pixels
# Distance between finger 0 and finger 5: 7.07 pixels
# Distance between finger 1 and finger 3: 47.51 pixels
# Distance between finger 1 and finger 4: 93.01 pixels
# Distance between finger 1 and finger 5: 159.01 pixels
# Distance between finger 2 and finger 4: 57.70 pixels
# Distance between finger 2 and finger 5: 160.11 pixels
# Distance between finger 3 and finger 5: 125.06 pixels
# Distance between finger 0 and finger 2: 151.86 pixels
# Distance between finger 0 and finger 3: 145.77 pixels
# Distance between finger 0 and finger 4: 117.11 pixels
# Distance between finger 0 and finger 5: 16.64 pixels
# Distance between finger 1 and finger 3: 47.01 pixels
# Distance between finger 1 and finger 4: 93.01 pixels
# Distance between finger 1 and finger 5: 168.37 pixels
# Distance between finger 2 and finger 4: 53.14 pixels
# Distance between finger 2 and finger 5: 162.16 pixels
# Distance between finger 3 and finger 5: 131.75 pixels
# Distance between finger 0 and finger 2: 135.92 pixels
# Distance between finger 0 and finger 3: 138.25 pixels
# Distance between finger 0 and finger 4: 115.97 pixels
# Distance between finger 0 and finger 5: 69.31 pixels
# Distance between finger 1 and finger 3: 48.30 pixels
# Distance between finger 1 and finger 4: 92.05 pixels
# Distance between finger 1 and finger 5: 142.21 pixels
# Distance between finger 2 and finger 4: 52.55 pixels
# Distance between finger 2 and finger 5: 120.22 pixels
# Distance between finger 3 and finger 5: 75.59 pixels
# Distance between finger 0 and finger 2: 121.50 pixels
# Distance between finger 0 and finger 3: 153.94 pixels
# Distance between finger 0 and finger 4: 155.08 pixels
# Distance between finger 0 and finger 5: 169.10 pixels
# Distance between finger 1 and finger 3: 50.99 pixels
# Distance between finger 1 and finger 4: 78.23 pixels
# Distance between finger 1 and finger 5: 138.25 pixels
# Distance between finger 2 and finger 4: 35.78 pixels
# Distance between finger 2 and finger 5: 104.31 pixels
# Distance between finger 3 and finger 5: 68.82 pixels
# Distance between finger 0 and finger 2: 124.19 pixels
# Distance between finger 0 and finger 3: 162.11 pixels
# Distance between finger 0 and finger 4: 167.09 pixels
# Distance between finger 0 and finger 5: 182.48 pixels
# Distance between finger 1 and finger 3: 52.39 pixels
# Distance between finger 1 and finger 4: 80.10 pixels
# Distance between finger 1 and finger 5: 134.89 pixels
# Distance between finger 2 and finger 4: 36.24 pixels
# Distance between finger 2 and finger 5: 99.86 pixels
# Distance between finger 3 and finger 5: 64.03 pixels
# Distance between finger 0 and finger 2: 139.29 pixels
# Distance between finger 0 and finger 3: 172.20 pixels
# Distance between finger 0 and finger 4: 187.88 pixels
# Distance between finger 0 and finger 5: 211.30 pixels
# Distance between finger 1 and finger 3: 38.01 pixels
# Distance between finger 1 and finger 4: 78.10 pixels
# Distance between finger 1 and finger 5: 145.50 pixels
# Distance between finger 2 and finger 4: 48.75 pixels
# Distance between finger 2 and finger 5: 124.81 pixels
# Distance between finger 3 and finger 5: 77.78 pixels
# Distance between finger 0 and finger 2: 125.92 pixels
# Distance between finger 0 and finger 3: 166.97 pixels
# Distance between finger 0 and finger 4: 186.13 pixels
# Distance between finger 0 and finger 5: 215.19 pixels
# Distance between finger 1 and finger 3: 50.09 pixels
# Distance between finger 1 and finger 4: 88.57 pixels
# Distance between finger 1 and finger 5: 148.12 pixels
# Distance between finger 2 and finger 4: 44.64 pixels
# Distance between finger 2 and finger 5: 111.40 pixels
# Distance between finger 3 and finger 5: 67.74 pixels
# Distance between finger 0 and finger 2: 109.59 pixels
# Distance between finger 0 and finger 3: 139.46 pixels
# Distance between finger 0 and finger 4: 169.53 pixels
# Distance between finger 0 and finger 5: 203.48 pixels
# Distance between finger 1 and finger 3: 41.23 pixels
# Distance between finger 1 and finger 4: 82.73 pixels
# Distance between finger 1 and finger 5: 135.24 pixels
# Distance between finger 2 and finger 4: 42.01 pixels
# Distance between finger 2 and finger 5: 96.69 pixels
# Distance between finger 3 and finger 5: 56.30 pixels
# Distance between finger 0 and finger 2: 118.93 pixels
# Distance between finger 0 and finger 3: 160.70 pixels
# Distance between finger 0 and finger 4: 176.80 pixels
# Distance between finger 0 and finger 5: 209.75 pixels
# Distance between finger 1 and finger 3: 50.61 pixels
# Distance between finger 1 and finger 4: 87.69 pixels
# Distance between finger 1 and finger 5: 147.98 pixels
# Distance between finger 2 and finger 4: 45.22 pixels
# Distance between finger 2 and finger 5: 111.23 pixels
# Distance between finger 3 and finger 5: 66.21 pixels
# Distance between finger 0 and finger 2: 121.49 pixels
# Distance between finger 0 and finger 3: 161.45 pixels
# Distance between finger 0 and finger 4: 178.24 pixels
# Distance between finger 0 and finger 5: 209.33 pixels
# Distance between finger 1 and finger 3: 50.09 pixels
# Distance between finger 1 and finger 4: 87.46 pixels
# Distance between finger 1 and finger 5: 148.95 pixels
# Distance between finger 2 and finger 4: 43.97 pixels
# Distance between finger 2 and finger 5: 111.89 pixels
# Distance between finger 3 and finger 5: 68.48 pixels
# Distance between finger 0 and finger 2: 119.97 pixels
# Distance between finger 0 and finger 3: 162.83 pixels
# Distance between finger 0 and finger 4: 181.79 pixels
# Distance between finger 0 and finger 5: 210.38 pixels
# Distance between finger 1 and finger 3: 51.48 pixels
# Distance between finger 1 and finger 4: 89.94 pixels
# Distance between finger 1 and finger 5: 151.25 pixels
# Distance between finger 2 and finger 4: 45.61 pixels
# Distance between finger 2 and finger 5: 115.83 pixels
# Distance between finger 3 and finger 5: 71.56 pixels
# Distance between finger 0 and finger 2: 119.40 pixels
# Distance between finger 0 and finger 3: 166.74 pixels
# Distance between finger 0 and finger 4: 188.11 pixels
# Distance between finger 0 and finger 5: 212.88 pixels
# Distance between finger 1 and finger 3: 54.08 pixels
# Distance between finger 1 and finger 4: 93.17 pixels
# Distance between finger 1 and finger 5: 146.77 pixels
# Distance between finger 2 and finger 4: 47.07 pixels
# Distance between finger 2 and finger 5: 110.57 pixels
# Distance between finger 3 and finger 5: 65.19 pixels
# Distance between finger 0 and finger 2: 111.66 pixels
# Distance between finger 0 and finger 3: 159.88 pixels
# Distance between finger 0 and finger 4: 178.28 pixels
# Distance between finger 0 and finger 5: 203.79 pixels
# Distance between finger 1 and finger 3: 53.26 pixels
# Distance between finger 1 and finger 4: 87.64 pixels
# Distance between finger 1 and finger 5: 139.06 pixels
# Distance between finger 2 and finger 4: 43.93 pixels
# Distance between finger 2 and finger 5: 105.11 pixels
# Distance between finger 3 and finger 5: 62.18 pixels
# Distance between finger 0 and finger 2: 103.41 pixels
# Distance between finger 0 and finger 3: 140.89 pixels
# Distance between finger 0 and finger 4: 156.46 pixels
# Distance between finger 0 and finger 5: 179.74 pixels
# Distance between finger 1 and finger 3: 41.87 pixels
# Distance between finger 1 and finger 4: 74.22 pixels
# Distance between finger 1 and finger 5: 122.20 pixels
# Distance between finger 2 and finger 4: 41.00 pixels
# Distance between finger 2 and finger 5: 96.21 pixels
# Distance between finger 3 and finger 5: 55.90 pixels
# Distance between finger 0 and finger 2: 93.06 pixels
# Distance between finger 0 and finger 3: 90.97 pixels
# Distance between finger 0 and finger 4: 119.00 pixels
# Distance between finger 0 and finger 5: 123.46 pixels
# Distance between finger 1 and finger 3: 171.81 pixels
# Distance between finger 1 and finger 4: 192.32 pixels
# Distance between finger 1 and finger 5: 184.76 pixels
# Distance between finger 2 and finger 4: 31.78 pixels
# Distance between finger 2 and finger 5: 51.24 pixels
# Distance between finger 3 and finger 5: 28.43 pixels
# Distance between finger 0 and finger 2: 83.01 pixels
# Distance between finger 0 and finger 3: 76.16 pixels
# Distance between finger 0 and finger 4: 108.17 pixels
# Distance between finger 0 and finger 5: 107.81 pixels
# Distance between finger 1 and finger 3: 156.11 pixels
# Distance between finger 1 and finger 4: 183.44 pixels
# Distance between finger 1 and finger 5: 174.06 pixels
# Distance between finger 2 and finger 4: 36.06 pixels
# Distance between finger 2 and finger 5: 52.00 pixels
# Distance between finger 3 and finger 5: 29.73 pixels
# Distance between finger 0 and finger 2: 86.15 pixels
# Distance between finger 0 and finger 3: 85.00 pixels
# Distance between finger 0 and finger 4: 108.72 pixels
# Distance between finger 0 and finger 5: 108.37 pixels
# Distance between finger 1 and finger 3: 168.08 pixels
# Distance between finger 1 and finger 4: 187.97 pixels
# Distance between finger 1 and finger 5: 179.89 pixels
# Distance between finger 2 and finger 4: 28.18 pixels
# Distance between finger 2 and finger 5: 45.28 pixels
# Distance between finger 3 and finger 5: 26.91 pixels
# Distance between finger 0 and finger 2: 95.01 pixels
# Distance between finger 0 and finger 3: 85.42 pixels
# Distance between finger 0 and finger 4: 108.60 pixels
# Distance between finger 0 and finger 5: 110.11 pixels
# Distance between finger 1 and finger 3: 175.62 pixels
# Distance between finger 1 and finger 4: 193.60 pixels
# Distance between finger 1 and finger 5: 186.07 pixels
# Distance between finger 2 and finger 4: 28.23 pixels
# Distance between finger 2 and finger 5: 46.39 pixels
# Distance between finger 3 and finger 5: 26.25 pixels
# Distance between finger 0 and finger 2: 96.05 pixels
# Distance between finger 0 and finger 3: 84.53 pixels
# Distance between finger 0 and finger 4: 108.00 pixels
# Distance between finger 0 and finger 5: 110.11 pixels
# Distance between finger 1 and finger 3: 176.08 pixels
# Distance between finger 1 and finger 4: 194.88 pixels
# Distance between finger 1 and finger 5: 187.88 pixels
# Distance between finger 2 and finger 4: 27.73 pixels
# Distance between finger 2 and finger 5: 46.27 pixels
# Distance between finger 3 and finger 5: 27.02 pixels
# Distance between finger 0 and finger 2: 97.02 pixels
# Distance between finger 0 and finger 3: 84.53 pixels
# Distance between finger 0 and finger 4: 106.40 pixels
# Distance between finger 0 and finger 5: 110.26 pixels
# Distance between finger 1 and finger 3: 176.82 pixels
# Distance between finger 1 and finger 4: 193.60 pixels
# Distance between finger 1 and finger 5: 187.88 pixels
# Distance between finger 2 and finger 4: 26.93 pixels
# Distance between finger 2 and finger 5: 47.38 pixels
# Distance between finger 3 and finger 5: 27.20 pixels
# Distance between finger 0 and finger 2: 100.00 pixels
# Distance between finger 0 and finger 3: 62.48 pixels
# Distance between finger 0 and finger 4: 110.11 pixels
# Distance between finger 0 and finger 5: 119.47 pixels
# Distance between finger 1 and finger 3: 148.33 pixels
# Distance between finger 1 and finger 4: 190.52 pixels
# Distance between finger 1 and finger 5: 189.43 pixels
# Distance between finger 2 and finger 4: 47.63 pixels
# Distance between finger 2 and finger 5: 59.48 pixels
# Distance between finger 3 and finger 5: 23.85 pixels
# Distance between finger 0 and finger 2: 109.13 pixels
# Distance between finger 0 and finger 3: 63.51 pixels
# Distance between finger 0 and finger 4: 53.16 pixels
# Distance between finger 0 and finger 5: 61.40 pixels
# Distance between finger 1 and finger 3: 54.04 pixels
# Distance between finger 1 and finger 4: 161.64 pixels
# Distance between finger 1 and finger 5: 169.96 pixels
# Distance between finger 2 and finger 4: 116.30 pixels
# Distance between finger 2 and finger 5: 120.70 pixels
# Distance between finger 3 and finger 5: 22.09 pixels
# Distance between finger 0 and finger 2: 122.59 pixels
# Distance between finger 0 and finger 3: 144.59 pixels
# Distance between finger 0 and finger 4: 46.57 pixels
# Distance between finger 0 and finger 5: 54.38 pixels
# Distance between finger 1 and finger 3: 57.63 pixels
# Distance between finger 1 and finger 4: 168.25 pixels
# Distance between finger 1 and finger 5: 176.88 pixels
# Distance between finger 2 and finger 4: 190.65 pixels
# Distance between finger 2 and finger 5: 194.59 pixels
# Distance between finger 3 and finger 5: 17.03 pixels
# Distance between finger 0 and finger 2: 120.31 pixels
# Distance between finger 0 and finger 3: 147.22 pixels
# Distance between finger 0 and finger 4: 50.70 pixels
# Distance between finger 0 and finger 5: 58.82 pixels
# Distance between finger 1 and finger 3: 61.72 pixels
# Distance between finger 1 and finger 4: 170.86 pixels
# Distance between finger 1 and finger 5: 178.73 pixels
# Distance between finger 2 and finger 4: 195.87 pixels
# Distance between finger 2 and finger 5: 199.47 pixels
# Distance between finger 3 and finger 5: 15.03 pixels
# Distance between finger 0 and finger 2: 119.95 pixels
# Distance between finger 0 and finger 3: 142.59 pixels
# Distance between finger 0 and finger 4: 54.42 pixels
# Distance between finger 0 and finger 5: 68.24 pixels
# Distance between finger 1 and finger 3: 58.26 pixels
# Distance between finger 1 and finger 4: 173.97 pixels
# Distance between finger 1 and finger 5: 187.96 pixels
# Distance between finger 2 and finger 4: 195.63 pixels
# Distance between finger 2 and finger 5: 204.71 pixels
# Distance between finger 3 and finger 5: 20.62 pixels
# Distance between finger 0 and finger 2: 119.95 pixels
# Distance between finger 0 and finger 3: 144.59 pixels
# Distance between finger 0 and finger 4: 51.26 pixels
# Distance between finger 0 and finger 5: 60.61 pixels
# Distance between finger 1 and finger 3: 59.55 pixels
# Distance between finger 1 and finger 4: 170.84 pixels
# Distance between finger 1 and finger 5: 180.09 pixels
# Distance between finger 2 and finger 4: 194.49 pixels
# Distance between finger 2 and finger 5: 198.40 pixels
# Distance between finger 3 and finger 5: 19.00 pixels
# Distance between finger 0 and finger 2: 125.40 pixels
# Distance between finger 0 and finger 3: 145.12 pixels
# Distance between finger 0 and finger 4: 46.49 pixels
# Distance between finger 0 and finger 5: 58.01 pixels
# Distance between finger 1 and finger 3: 56.22 pixels
# Distance between finger 1 and finger 4: 171.28 pixels
# Distance between finger 1 and finger 5: 183.17 pixels
# Distance between finger 2 and finger 4: 190.87 pixels
# Distance between finger 2 and finger 5: 197.95 pixels
# Distance between finger 3 and finger 5: 19.24 pixels
# Distance between finger 0 and finger 2: 122.10 pixels
# Distance between finger 0 and finger 3: 114.74 pixels
# Distance between finger 0 and finger 4: 43.86 pixels
# Distance between finger 0 and finger 5: 53.76 pixels
# Distance between finger 1 and finger 3: 40.20 pixels
# Distance between finger 1 and finger 4: 165.95 pixels
# Distance between finger 1 and finger 5: 174.07 pixels
# Distance between finger 2 and finger 4: 157.09 pixels
# Distance between finger 2 and finger 5: 160.96 pixels
# Distance between finger 3 and finger 5: 19.03 pixels
# Distance between finger 0 and finger 2: 122.30 pixels
# Distance between finger 0 and finger 3: 80.01 pixels
# Distance between finger 0 and finger 4: 14.32 pixels
# Distance between finger 0 and finger 5: 43.19 pixels
# Distance between finger 1 and finger 3: 65.39 pixels
# Distance between finger 1 and finger 4: 127.41 pixels
# Distance between finger 1 and finger 5: 163.93 pixels
# Distance between finger 2 and finger 4: 78.45 pixels
# ...
# Distance between finger 2 and finger 4: 29.53 pixels
# Distance between finger 2 and finger 5: 155.24 pixels
# Distance between finger 3 and finger 5: 136.72 pixels
# Distance between finger 0 and finger 2: 45.80 pixels
# Distance between finger 0 and finger 3: 31.32 pixels
# Distance between finger 0 and finger 4: 30.81 pixels
# Distance between finger 0 and finger 5: 11.05 pixels
# Distance between finger 1 and finger 3: 63.51 pixels
# Distance between finger 1 and finger 4: 72.01 pixels
# Distance between finger 1 and finger 5: 54.59 pixels
# Distance between finger 2 and finger 4: 16.00 pixels
# Distance between finger 2 and finger 5: 36.89 pixels
# Distance between finger 3 and finger 5: 31.26 pixels
# Distance between finger 0 and finger 2: 13.89 pixels
# Distance between finger 0 and finger 3: 62.17 pixels
# Distance between finger 0 and finger 4: 74.67 pixels
# Distance between finger 0 and finger 5: 70.84 pixels
# Distance between finger 1 and finger 3: 52.55 pixels
# Distance between finger 1 and finger 4: 66.73 pixels
# Distance between finger 1 and finger 5: 67.80 pixels
# Distance between finger 2 and finger 4: 16.64 pixels
# Distance between finger 2 and finger 5: 35.90 pixels
# Distance between finger 3 and finger 5: 27.02 pixels
# Distance between finger 0 and finger 2: 77.16 pixels
# Distance between finger 0 and finger 3: 49.37 pixels
# Distance between finger 0 and finger 4: 62.59 pixels
# Distance between finger 0 and finger 5: 58.31 pixels
# Distance between finger 1 and finger 3: 126.00 pixels
# Distance between finger 1 and finger 4: 138.29 pixels
# Distance between finger 1 and finger 5: 132.10 pixels
# Distance between finger 2 and finger 4: 14.42 pixels
# Distance between finger 2 and finger 5: 16.76 pixels
# Distance between finger 3 and finger 5: 10.63 pixels
# Distance between finger 0 and finger 2: 14.56 pixels
# Distance between finger 0 and finger 3: 40.05 pixels
# Distance between finger 0 and finger 4: 49.34 pixels
# Distance between finger 0 and finger 5: 47.43 pixels
# Distance between finger 1 and finger 3: 54.33 pixels
# Distance between finger 1 and finger 4: 63.89 pixels
# Distance between finger 1 and finger 5: 61.40 pixels
# Distance between finger 2 and finger 4: 14.76 pixels
# Distance between finger 2 and finger 5: 25.02 pixels
# Distance between finger 3 and finger 5: 14.42 pixels
# Distance between finger 0 and finger 2: 41.01 pixels
# Distance between finger 0 and finger 3: 58.25 pixels
# Distance between finger 0 and finger 4: 67.23 pixels
# Distance between finger 0 and finger 5: 70.29 pixels
# Distance between finger 1 and finger 3: 19.42 pixels
# Distance between finger 1 and finger 4: 32.65 pixels
# Distance between finger 1 and finger 5: 45.88 pixels
# Distance between finger 2 and finger 4: 14.87 pixels
# Distance between finger 2 and finger 5: 33.14 pixels
# Distance between finger 3 and finger 5: 20.62 pixels
# Distance between finger 0 and finger 2: 29.61 pixels
# Distance between finger 0 and finger 3: 42.05 pixels
# Distance between finger 0 and finger 4: 51.24 pixels
# Distance between finger 0 and finger 5: 57.28 pixels
# Distance between finger 1 and finger 3: 15.26 pixels
# Distance between finger 1 and finger 4: 29.00 pixels
# Distance between finger 1 and finger 5: 47.54 pixels
# Distance between finger 2 and finger 4: 14.76 pixels
# Distance between finger 2 and finger 5: 38.01 pixels
# Distance between finger 3 and finger 5: 26.25 pixels
# Distance between finger 0 and finger 2: 29.07 pixels
# Distance between finger 0 and finger 3: 39.20 pixels
# Distance between finger 0 and finger 4: 47.30 pixels
# Distance between finger 0 and finger 5: 52.35 pixels
# Distance between finger 1 and finger 3: 15.81 pixels
# Distance between finger 1 and finger 4: 31.24 pixels
# Distance between finger 1 and finger 5: 50.45 pixels
# Distance between finger 2 and finger 4: 16.55 pixels
# Distance between finger 2 and finger 5: 40.01 pixels
# Distance between finger 3 and finger 5: 26.25 pixels
# Distance between finger 0 and finger 2: 25.32 pixels
# Distance between finger 0 and finger 3: 37.36 pixels
# Distance between finger 0 and finger 4: 47.01 pixels
# Distance between finger 0 and finger 5: 55.22 pixels
# Distance between finger 1 and finger 3: 12.53 pixels
# Distance between finger 1 and finger 4: 24.84 pixels
# Distance between finger 1 and finger 5: 41.59 pixels
# Distance between finger 2 and finger 4: 13.93 pixels
# Distance between finger 2 and finger 5: 35.23 pixels
# Distance between finger 3 and finger 5: 23.77 pixels
# Distance between finger 0 and finger 2: 25.71 pixels
# Distance between finger 0 and finger 3: 38.63 pixels
# Distance between finger 0 and finger 4: 49.65 pixels
# Distance between finger 0 and finger 5: 55.47 pixels
# Distance between finger 1 and finger 3: 13.60 pixels
# Distance between finger 1 and finger 4: 27.20 pixels
# Distance between finger 1 and finger 5: 40.45 pixels
# Distance between finger 2 and finger 4: 14.87 pixels
# Distance between finger 2 and finger 5: 32.39 pixels
# Distance between finger 3 and finger 5: 20.59 pixels
# Distance between finger 0 and finger 2: 31.05 pixels
# Distance between finger 0 and finger 3: 41.63 pixels
# Distance between finger 0 and finger 4: 51.61 pixels
# Distance between finger 0 and finger 5: 54.92 pixels
# Distance between finger 1 and finger 3: 12.04 pixels
# Distance between finger 1 and finger 4: 25.06 pixels
# Distance between finger 1 and finger 5: 38.00 pixels
# Distance between finger 2 and finger 4: 13.60 pixels
# Distance between finger 2 and finger 5: 30.08 pixels
# Distance between finger 3 and finger 5: 20.00 pixels
# Distance between finger 0 and finger 2: 28.64 pixels
# Distance between finger 0 and finger 3: 43.42 pixels
# Distance between finger 0 and finger 4: 54.04 pixels
# Distance between finger 0 and finger 5: 57.31 pixels
# Distance between finger 1 and finger 3: 15.00 pixels
# Distance between finger 1 and finger 4: 27.20 pixels
# Distance between finger 1 and finger 5: 38.05 pixels
# Distance between finger 2 and finger 4: 13.60 pixels
# Distance between finger 2 and finger 5: 30.68 pixels
# Distance between finger 3 and finger 5: 21.26 pixels
# Distance between finger 0 and finger 2: 31.05 pixels
# Distance between finger 0 and finger 3: 42.54 pixels
# Distance between finger 0 and finger 4: 52.70 pixels
# Distance between finger 0 and finger 5: 53.01 pixels
# Distance between finger 1 and finger 3: 12.73 pixels
# Distance between finger 1 and finger 4: 25.24 pixels
# Distance between finger 1 and finger 5: 35.01 pixels
# Distance between finger 2 and finger 4: 13.00 pixels
# Distance between finger 2 and finger 5: 27.20 pixels
# Distance between finger 3 and finger 5: 19.10 pixels
# Distance between finger 0 and finger 2: 33.53 pixels
# Distance between finger 0 and finger 3: 42.54 pixels
# Distance between finger 0 and finger 4: 51.04 pixels
# Distance between finger 0 and finger 5: 51.87 pixels
# Distance between finger 1 and finger 3: 9.90 pixels
# Distance between finger 1 and finger 4: 21.47 pixels
# Distance between finger 1 and finger 5: 33.14 pixels
# Distance between finger 2 and finger 4: 12.37 pixels
# Distance between finger 2 and finger 5: 27.86 pixels
# Distance between finger 3 and finger 5: 19.10 pixels
# Distance between finger 0 and finger 2: 33.62 pixels
# Distance between finger 0 and finger 3: 43.38 pixels
# Distance between finger 0 and finger 4: 53.25 pixels
# Distance between finger 0 and finger 5: 46.23 pixels
# Distance between finger 1 and finger 3: 10.00 pixels
# Distance between finger 1 and finger 4: 21.40 pixels
# Distance between finger 1 and finger 5: 23.09 pixels
# Distance between finger 2 and finger 4: 12.08 pixels
# Distance between finger 2 and finger 5: 19.72 pixels
# Distance between finger 3 and finger 5: 16.16 pixels
# Distance between finger 0 and finger 2: 35.44 pixels
# Distance between finger 0 and finger 3: 44.94 pixels
# Distance between finger 0 and finger 4: 53.71 pixels
# Distance between finger 0 and finger 5: 46.10 pixels
# Distance between finger 1 and finger 3: 10.00 pixels
# Distance between finger 1 and finger 4: 20.62 pixels
# Distance between finger 1 and finger 5: 20.02 pixels
# Distance between finger 2 and finger 4: 11.18 pixels
# Distance between finger 2 and finger 5: 15.65 pixels
# Distance between finger 3 and finger 5: 12.65 pixels
# Distance between finger 0 and finger 2: 36.06 pixels
# Distance between finger 0 and finger 3: 44.38 pixels
# Distance between finger 0 and finger 4: 52.84 pixels
# Distance between finger 0 and finger 5: 46.75 pixels
# Distance between finger 1 and finger 3: 8.60 pixels
# Distance between finger 1 and finger 4: 18.44 pixels
# Distance between finger 1 and finger 5: 19.03 pixels
# Distance between finger 2 and finger 4: 10.30 pixels
# Distance between finger 2 and finger 5: 15.23 pixels
# Distance between finger 3 and finger 5: 12.08 pixels
# Distance between finger 0 and finger 2: 36.88 pixels
# Distance between finger 0 and finger 3: 44.92 pixels
# Distance between finger 0 and finger 4: 53.31 pixels
# Distance between finger 0 and finger 5: 51.40 pixels
# Distance between finger 1 and finger 3: 8.60 pixels
# Distance between finger 1 and finger 4: 18.38 pixels
# Distance between finger 1 and finger 5: 23.54 pixels
# Distance between finger 2 and finger 4: 10.00 pixels
# Distance between finger 2 and finger 5: 18.11 pixels
# Distance between finger 3 and finger 5: 12.81 pixels
# Distance between finger 0 and finger 2: 40.26 pixels
# Distance between finger 0 and finger 3: 47.43 pixels
# Distance between finger 0 and finger 4: 56.36 pixels
# Distance between finger 0 and finger 5: 55.61 pixels
# Distance between finger 1 and finger 3: 7.81 pixels
# Distance between finger 1 and finger 4: 18.44 pixels
# Distance between finger 1 and finger 5: 24.52 pixels
# Distance between finger 2 and finger 4: 10.82 pixels
# Distance between finger 2 and finger 5: 19.03 pixels
# Distance between finger 3 and finger 5: 12.21 pixels
# Distance between finger 0 and finger 2: 40.79 pixels
# Distance between finger 0 and finger 3: 48.76 pixels
# Distance between finger 0 and finger 4: 57.38 pixels
# Distance between finger 0 and finger 5: 55.80 pixels
# Distance between finger 1 and finger 3: 8.60 pixels
# Distance between finger 1 and finger 4: 19.10 pixels
# Distance between finger 1 and finger 5: 25.50 pixels
# Distance between finger 2 and finger 4: 10.82 pixels
# Distance between finger 2 and finger 5: 20.10 pixels
# Distance between finger 3 and finger 5: 13.60 pixels
# Distance between finger 0 and finger 2: 47.07 pixels
# Distance between finger 0 and finger 3: 55.32 pixels
# Distance between finger 0 and finger 4: 65.46 pixels
# Distance between finger 0 and finger 5: 60.75 pixels
# Distance between finger 1 and finger 3: 8.25 pixels
# Distance between finger 1 and finger 4: 19.42 pixels
# Distance between finger 1 and finger 5: 23.54 pixels
# Distance between finger 2 and finger 4: 12.04 pixels
# Distance between finger 2 and finger 5: 21.21 pixels
# Distance between finger 3 and finger 5: 16.28 pixels
# Distance between finger 0 and finger 2: 42.95 pixels
# Distance between finger 0 and finger 3: 53.37 pixels
# Distance between finger 0 and finger 4: 63.25 pixels
# Distance between finger 0 and finger 5: 61.06 pixels
# Distance between finger 1 and finger 3: 10.44 pixels
# Distance between finger 1 and finger 4: 21.10 pixels
# Distance between finger 1 and finger 5: 25.08 pixels
# Distance between finger 2 and finger 4: 11.31 pixels
# Distance between finger 2 and finger 5: 20.00 pixels
# Distance between finger 3 and finger 5: 14.42 pixels
# Distance between finger 0 and finger 2: 47.07 pixels
# Distance between finger 0 and finger 3: 56.52 pixels
# Distance between finger 0 and finger 4: 65.79 pixels
# Distance between finger 0 and finger 5: 60.75 pixels
# Distance between finger 1 and finger 3: 9.49 pixels
# Distance between finger 1 and finger 4: 20.00 pixels
# Distance between finger 1 and finger 5: 23.54 pixels
# Distance between finger 2 and finger 4: 11.40 pixels
# Distance between finger 2 and finger 5: 20.40 pixels
# Distance between finger 3 and finger 5: 15.56 pixels
# Distance between finger 0 and finger 2: 44.15 pixels
# Distance between finger 0 and finger 3: 53.60 pixels
# Distance between finger 0 and finger 4: 63.57 pixels
# Distance between finger 0 and finger 5: 60.75 pixels
# Distance between finger 1 and finger 3: 9.49 pixels
# Distance between finger 1 and finger 4: 20.25 pixels
# Distance between finger 1 and finger 5: 24.35 pixels
# Distance between finger 2 and finger 4: 11.31 pixels
# Distance between finger 2 and finger 5: 20.02 pixels
# Distance between finger 3 and finger 5: 15.00 pixels
# Distance between finger 0 and finger 2: 45.89 pixels
# Distance between finger 0 and finger 3: 54.57 pixels
# Distance between finger 0 and finger 4: 63.57 pixels
# Distance between finger 0 and finger 5: 58.52 pixels
# Distance between finger 1 and finger 3: 8.94 pixels
# Distance between finger 1 and finger 4: 19.21 pixels
# Distance between finger 1 and finger 5: 23.35 pixels
# Distance between finger 2 and finger 4: 10.63 pixels
# Distance between finger 2 and finger 5: 19.42 pixels
# Distance between finger 3 and finger 5: 15.56 pixels
# Distance between finger 0 and finger 2: 50.22 pixels
# Distance between finger 0 and finger 3: 60.44 pixels
# Distance between finger 0 and finger 4: 70.01 pixels
# Distance between finger 0 and finger 5: 70.33 pixels
# Distance between finger 1 and finger 3: 10.82 pixels
# Distance between finger 1 and finger 4: 21.93 pixels
# Distance between finger 1 and finger 5: 26.83 pixels
# Distance between finger 2 and finger 4: 11.40 pixels
# Distance between finger 2 and finger 5: 18.25 pixels
# Distance between finger 3 and finger 5: 9.85 pixels
# Distance between finger 0 and finger 2: 49.04 pixels
# Distance between finger 0 and finger 3: 58.69 pixels
# Distance between finger 0 and finger 4: 71.12 pixels
# Distance between finger 0 and finger 5: 78.23 pixels
# Distance between finger 1 and finger 3: 10.00 pixels
# Distance between finger 1 and finger 4: 23.35 pixels
# Distance between finger 1 and finger 5: 32.02 pixels
# Distance between finger 2 and finger 4: 13.45 pixels
# Distance between finger 2 and finger 5: 22.47 pixels
# Distance between finger 3 and finger 5: 9.49 pixels
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       7 while True:
#       8     ret, frame = cap.read()
# ----> 9     hands, frame = detector.findHands(frame)
#      11     if hands:
#      12         hand = hands[0]
#
# File c:\Users\parspc42540942\AppData\Local\Programs\Python\Python310\lib\site-packages\cvzone\HandTrackingModule.py:55, in HandDetector.findHands(self, img, draw, flipType)
#      48 """
#      49 Finds hands in a BGR image.
#      50 :param img: Image to find the hands in.
#      51 :param draw: Flag to draw the output on the image.
#      52 :return: Image with or without drawings
#      53 """
#      54 imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ---> 55 self.results = self.hands.process(imgRGB)
#      56 allHands = []
#      57 h, w, c = img.shape
#
# File c:\Users\parspc42540942\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\python\solutions\hands.py:153, in Hands.process(self, image)
#     132 def process(self, image: np.ndarray) -> NamedTuple:
#     133   """Processes an RGB image and returns the hand landmarks and handedness of each detected hand.
#     134
#     135   Args:
#    (...)
#     150          right hand) of the detected hand.
#     151   """
# --> 153   return super().process(input_data={'image': image})
#
# File c:\Users\parspc42540942\AppData\Local\Programs\Python\Python310\lib\site-packages\mediapipe\python\solution_base.py:372, in SolutionBase.process(self, input_data)
#     366   else:
#     367     self._graph.add_packet_to_input_stream(
#     368         stream=stream_name,
#     369         packet=self._make_packet(input_stream_type,
#     370                                  data).at(self._simulated_timestamp))
# --> 372 self._graph.wait_until_idle()
#     373 # Create a NamedTuple object where the field names are mapping to the graph
#     374 # output stream names.
#     375 solution_outputs = collections.namedtuple(
#     376     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:
